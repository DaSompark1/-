# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
list_url = 'http://ac.qq.com/Comic/all/search/hot/page'

html = requests.get(list_url).text
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="zh-cn">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Tencent" name="Copyright"/>
# <meta content="腾讯动漫,动漫,腾讯漫画,漫画,动画,原创漫画,火影忍者,海贼王,代嫁丞相,超神灵主" name="Keywords"/>
# <meta content="腾讯原创动漫发行平台，中国最大最权威的正版动漫网站，汇集大陆、港台、日韩、欧美漫画家的海量作品,囊括当前最热门漫画：如火影忍者，海贼王，代嫁丞相，超神灵主等等漫画，通过全平台的优势，为上千万动漫爱好者提供海量优质漫画的在线阅读，为原创动漫作者提供施展才华的一站式服务，为中国的动漫产业打造梦想的舞台。" name="Description"/>
# <meta content="IE=edge; chrome=1" http-equiv="X-UA-Compatible"/>
# <title>全部 - 漫画检索 - 腾讯动漫官方网站</title>
# <link href="http://ac.gtimg.com/media/css/ac.global.css?v=20170622" media="screen" rel="stylesheet" type="text/css"/><!-- 样式文件 -->
# <link href="http://ac.gtimg.com/media/css/ac.page.comicall.css?v=20170622" media="screen" rel="stylesheet" type="text/css"/>
# </head>
# <body class="ret-bg-type-0 ui-bg-rank-change">
# <div id="loginframe" style="display:none;">
# <iframe frameborder="0" height="100%" id="login_ifr" name="login_ifr" scrolling="no" src="javascript://" width="100%"></iframe>
# </div>
# <script></script>
# <div class="mod-top-small-wr">
# <div class="ui-wm mod-top-small-head">
# <h1 class="mod-top-small-logo ui-left"><a href="/" title="腾讯动漫">腾讯动漫</a></h1>
# <ul class="mod-top-small-nav ui-left">
# <li><a href="/" title="首页">首页</a></li>
# <li><a href="/Comic/index/state/pink" title="全部作品">全部作品</a></li>
# <li><a href="/Jump" title="日漫">日漫</a></li>
# <li><a href="/Light" title="轻小说">轻小说</a></li>
# <li><a href="/Ground" target="_blank" title="福利社">福利社</a></li>
# <li><a href="http://comic.qq.com" target="_blank" title="资讯">资讯</a></li>
# <li><a href="/event/cartoon2016/index.html" title="动画">动画</a></li>
# <!--<li><a href="javascript:alert('敬请期待');" title="周边商城">周边商城</a></li>-->
# <li><a href="/Rank" title="排行榜">排行榜</a></li>
# <li><a href="/Home" title="个人中心">个人中心</a></li>
# <li><a href="http://m.ac.qq.com/event/downloadForPc/index.html" target="_blank" title="手机版">手机版</a></li>
# </ul>
# </div>
# </div> <div class="ui-wm ui-mb40 ui-mt40 clearfix">
# <div class="ret-side-wr ui-left">
# <div class="ret-tags-wr">
# <h2 class="ret-title">检索</h2>
# <div class="ret-check-all clearfix">
# <span class="ui-left ret-check-ft">全部 &gt;</span>
# </div>
# <div class="ret-tags-type">
# <h3 class="ret-tags-title ret-tags-sx">属性</h3>
# <div class="ret-tags-items single" id="p_vip">
# <a href="javascript:void(0)" title="全部">全部</a>
# <a href="javascript:void(0)" id="vip_2" title="付费">付费</a>
# <a href="javascript:void(0)" id="vip_1" title="免费">免费</a>
# <a href="javascript:void(0)" id="vip_3" style="display: none" title="VIP免费">VIP免费</a>
# </div>
# </div>
# <div class="ret-tags-type">
# <h3 class="ret-tags-title ret-tags-jd">进度</h3>
# <div class="ret-tags-items single" id="p_finish">
# <a href="javascript:void(0)" title="全部">全部</a>
# <a href="javascript:void(0)" id="finish_1" title="连载">连载</a>
# <a href="javascript:void(0)" id="finish_2" title="完结">完结</a>
# </div>
# </div>
# <div class="ret-tags-type">
# <h3 class="ret-tags-title ret-tags-bq">标签</h3>
# <div class="ret-tags-items single" id="p_theme">
# <a class="single" href="javascript:void(0)" title="全部">全部</a>
# <a href="javascript:void(0)" id="theme_40" title="其它">其它</a>
# </div>
# </div>
# <div class="ret-tags-type">
# <h3 class="ret-tags-title ret-tags-sz">受众</h3>
# <div class="ret-tags-items single" id="p_audience">
# <a href="javascript:void(0)" title="全部">全部</a>
# <a href="javascript:void(0)" id="audience_1" title="少年">少年</a>
# <a href="javascript:void(0)" id="audience_2" title="少女">少女</a>
# <a href="javascript:void(0)" id="audience_3" title="青年">青年</a>
# <a href="javascript:void(0)" id="audience_4" title="少儿">少儿</a>
# </div>
# </div>
# <div class="ret-tags-type">
# <h3 class="ret-tags-title ret-tags-sx">品质</h3>
# <div class="ret-tags-items single" id="p_state">
# <a class="single" href="javascript:void(0)" title="全部">全部</a>
# <a href="javascript:void(0)" id="state_right" title="签约">签约</a>
# <a href="javascript:void(0)" id="state_pink" title="精品">精品</a>
# <a href="javascript:void(0)" id="state_pop" title="热门">热门</a>
# <a class="single" href="javascript:void(0)" id="state_rookie" title="新手">新手</a>
# </div>
# </div>
# <div class="ret-tags-type">
# <h3 class="ret-tags-title ret-tags-lx">类型</h3>
# <div class="ret-tags-items single" id="p_type">
# <a class="single" href="javascript:void(0)" title="全部">全部</a>
# <a href="javascript:void(0)" id="type_3" title="故事漫画">故事漫画</a>
# <a href="javascript:void(0)" id="type_8" title="轻小说">轻小说</a>
# <a href="javascript:void(0)" id="type_2" title="四格">四格</a>
# <a href="javascript:void(0)" id="type_4" title="绘本">绘本</a>
# <a href="javascript:void(0)" id="type_1" title="单幅">单幅</a>
# <a href="javascript:void(0)" id="type_5" title="同人">同人</a>
# </div>
# </div>
# <div class="ret-tags-type">
# <h3 class="ret-tags-title ret-tags-dq">地区</h3>
# <div class="ret-tags-items single" id="p_nation">
# <a class="single" href="javascript:void(0)" title="全部">全部</a>
# <a href="javascript:void(0)" id="nation_1" title="内地">内地</a>
# <a href="javascript:void(0)" id="nation_2" title="港台">港台</a>
# <a href="javascript:void(0)" id="nation_3" title="韩国">韩国</a>
# <a href="javascript:void(0)" id="nation_4" title="日本">日本</a>
# </div>
# </div>
# <div class="ret-tags-type">
# <h3 class="ret-tags-title ret-tags-dq">版权</h3>
# <div class="ret-tags-items single" id="p_copyright">
# <a href="javascript:void(0)" title="全部">全部</a>
# <a href="javascript:void(0)" id="copyright_first" title="首发">首发</a>
# <a href="javascript:void(0)" id="copyright_sole" title="独家">独家</a>
# </div>
# </div>
# <div class="ret-tags-type last">
# <h3 class="ret-tags-title ret-tags-zm">字母</h3>
# <div class="ret-tags-items single" id="p_mark">
# <a href="javascript:void(0)" title="全部">全部</a>
# <a href="javascript:void(0)" id="mark_A" title="A">A</a>
# <a href="javascript:void(0)" id="mark_B" title="B">B</a>
# <a href="javascript:void(0)" id="mark_C" title="C">C</a>
# <a href="javascript:void(0)" id="mark_D" title="D">D</a>
# <a href="javascript:void(0)" id="mark_E" title="E">E</a>
# <a href="javascript:void(0)" id="mark_F" title="F">F</a>
# <a href="javascript:void(0)" id="mark_G" title="G">G</a>
# <a href="javascript:void(0)" id="mark_H" title="H">H</a>
# <a href="javascript:void(0)" id="mark_I" title="I">I</a>
# <a href="javascript:void(0)" id="mark_J" title="J">J</a>
# <a href="javascript:void(0)" id="mark_K" title="K">K</a>
# <a href="javascript:void(0)" id="mark_L" title="L">L</a>
# <a href="javascript:void(0)" id="mark_M" title="M">M</a>
# <a href="javascript:void(0)" id="mark_N" title="N">N</a>
# <a href="javascript:void(0)" id="mark_O" title="O">O</a>
# <a href="javascript:void(0)" id="mark_P" title="P">P</a>
# <a href="javascript:void(0)" id="mark_Q" title="Q">Q</a>
# <a href="javascript:void(0)" id="mark_R" title="R">R</a>
# <a href="javascript:void(0)" id="mark_S" title="S">S</a>
# <a href="javascript:void(0)" id="mark_T" title="T">T</a>
# <a href="javascript:void(0)" id="mark_U" title="U">U</a>
# <a href="javascript:void(0)" id="mark_V" title="V">V</a>
# <a href="javascript:void(0)" id="mark_W" title="W">W</a>
# <a href="javascript:void(0)" id="mark_X" title="X">X</a>
# <a href="javascript:void(0)" id="mark_Y" title="Y">Y</a>
# <a href="javascript:void(0)" id="mark_Z" title="Z">Z</a>
# <a href="javascript:void(0)" id="mark_9" title="0~9">0~9</a>
# </div>
# </div>
# </div>
# </div>
# <div class="ret-main-wr ui-mb40 ui-left">
# <div class="ret-main">
# <div class="ret-search-head clearfix">
# <ul class="ret-search-type ui-left" id="search-condition">
# <li class="active" id="time"><a class="ret-search-time" href="javascript:void(0)" title="点击后按时间排序">更新时间</a></li>
# <li id="hot"><a class="ret-search-rank" href="javascript:void(0)" title="点击后按人气从高到低">热门人气</a></li>
# </ul>
# <div class="ret-head-page ui-right" id="pagination1"></div>
# <span class="ret-result-num ui-right">共<em>27746</em>个结果</span>
# </div>
# <div class="ret-search-result">
# <ul class="ret-search-list clearfix">
# <li class="ret-search-item clearfix">
# <div class="ret-works-cover">
# <a class="mod-cover-list-thumb mod-cover-effect ui-db" href="/Comic/comicInfo/id/540627" target="_blank" title="通灵妃">
# <img class="lazy" data-original="https://manhua.qpic.cn/vertical/0/12_01_56_d15bc33636ef8d3f084e733e41310282_1515693408612.jpg/420" src="http://ac.gtimg.com/media/images/blank.gif"/>
# <span class="mod-layer-mask">  </span>
# </a>
# <p class="mod-cover-list-updata">
# <a class="mod-cover-list-mask" href="/Comic/comicInfo/id/540627" target="_blank"><span class="mod-cover-list-text">更新至139话</span></a>
# </p>
# </div>
# <div class="ret-works-info">
# <h3 class="ret-works-title clearfix">
# <a href="/Comic/comicInfo/id/540627" target="_blank" title="通灵妃">通灵妃</a>
# <i class="ui-icon-sign">签约</i>
# <i class="ui-icon-bout">精品</i>
# </h3>
# <p class="ret-works-author" title="肉肉 图：肉肉 文：肉肉">肉肉 图：肉肉 文：肉肉</p>
# <p class="ret-works-tags">
# <a href="/Comic/all/theme/15" target="_blank">恋爱</a>
# <a href="/Comic/all/theme/1" target="_blank">爆笑</a>
# <a href="/Comic/all/theme/36" target="_blank">唯美</a>
# <span>人气：<em>214.1亿</em></span>
# </p>
# <p class="ret-works-decs">【每周四，周日更新】丞相府大小姐千云兮自小身负异能，被视为不详之人养在灵云山上，16岁这年代替妹妹千...</p>
# <a class="ret-works-view ui-btn-pink" href="/Comic/comicInfo/id/540627" target="_blank">开始阅读</a>
# </div>
# </li>
# <li class="ret-search-item clearfix">
# <div class="ret-works-cover">
# <a class="mod-cover-list-thumb mod-cover-effect ui-db" href="/Comic/comicInfo/id/521825" target="_blank" title="妖怪名单">
# <img class="lazy" data-original="https://manhua.qpic.cn/vertical/0/17_16_12_5434c1b0f4bba96b9fae3c3cf244ed5f.jpg/420" src="http://ac.gtimg.com/media/images/blank.gif"/>
# <span class="mod-layer-mask">  </span>
# </a>
# <p class="mod-cover-list-updata">
# <a class="mod-cover-list-mask" href="/Comic/comicInfo/id/521825" target="_blank"><span class="mod-cover-list-text">更新至378话</span></a>
# </p>
# </div>
# <div class="ret-works-info">
# <h3 class="ret-works-title clearfix">
# <a href="/Comic/comicInfo/id/521825" target="_blank" title="妖怪名单">妖怪名单</a>
# <i class="ui-icon-sign">签约</i>
# <i class="ui-icon-bout">精品</i>
# </h3>
# <p class="ret-works-author" title="糖人家 图：西洛×刘OK 文：福瑞×猴淳良">糖人家 图：西洛×刘OK 文：福瑞×猴淳良</p>
# <p class="ret-works-tags">
# <a href="/Comic/all/theme/7" target="_blank">玄幻</a>
# <a href="/Comic/all/theme/13" target="_blank">后宫</a>
# <a href="/Comic/all/theme/15" target="_blank">恋爱</a>
# <span>人气：<em>210.7亿</em></span>
# </p>
# <p class="ret-works-decs">魅惑众生的九尾狐狸？吸人精气的合欢树妖？道家妹子求双修，仙家女神若即离。游走在这些危险分子中间可不是...</p>
# <a class="ret-works-view ui-btn-pink" href="/Comic/comicInfo/id/521825" target="_blank">开始阅读</a>
# </div>
# </li>
# <li class="ret-search-item clearfix">
# <div class="ret-works-cover">
# <a class="mod-cover-list-thumb mod-cover-effect ui-db" href="/Comic/comicInfo/id/17114" target="_blank" title="尸兄（我叫白小飞）">
# <img class="lazy" data-original="https://manhua.qpic.cn/vertical/0/11_21_41_bbe7bbc9e0c8d8f795ca9f8551e45362_1518356500845.jpg/420" src="http://ac.gtimg.com/media/images/blank.gif"/>
# <span class="mod-layer-mask">  </span>
# </a>
# <p class="mod-cover-list-updata">
# <a class="mod-cover-list-mask" href="/Comic/comicInfo/id/17114" target="_blank"><span class="mod-cover-list-text">更新至355话</span></a>
# </p>
# </div>
# <div class="ret-works-info">
# <h3 class="ret-works-title clearfix">
# <a href="/Comic/comicInfo/id/17114" target="_blank" title="尸兄（我叫白小飞）">尸兄（我叫白小</a>
# <i class="ui-icon-sign">签约</i>
# <i class="ui-icon-bout">精品</i>
# </h3>
# <p class="ret-works-author" title="七度魚 图：七度魚 文：七度魚">七度魚 图：七度魚 文：七度魚</p>
# <p class="ret-works-tags">
# <a href="/Comic/all/theme/4" target="_blank">恐怖</a>
# <a href="/Comic/all/theme/1" target="_blank">爆笑</a>
# <a href="/Comic/all/theme/3" target="_blank">冒险</a>
# <span>人气：<em>175.3亿</em></span>
# </p>
# <p class="ret-works-decs">即将毁灭的世界......每周更新...</p>
# <a class="ret-works-view ui-btn-pink" href="/Comic/comicInfo/id/17114" target="_blank">开始阅读</a>
# </div>
# </li>
# <li class="ret-search-item clearfix">
# <div class="ret-works-cover">
# <a class="mod-cover-list-thumb mod-cover-effect ui-db" href="/Comic/comicInfo/id/519855" target="_blank" title="王牌御史">
# <img class="lazy" data-original="https://manhua.qpic.cn/vertical/0/09_23_24_7d08b6d89edd4db48477940bce75d708_1520609069014.JPG/420" src="http://ac.gtimg.com/media/images/blank.gif"/>
# <span class="mod-layer-mask">  </span>
# </a>
# <p class="mod-cover-list-updata">
# <a class="mod-cover-list-mask" href="/Comic/comicInfo/id/519855" target="_blank"><span class="mod-cover-list-text">更新至381话</span></a>
# </p>
# </div>
# <div class="ret-works-info">
# <h3 class="ret-works-title clearfix">
# <a href="/Comic/comicInfo/id/519855" target="_blank" title="王牌御史">王牌御史</a>
# <i class="ui-icon-sign">签约</i>
# <i class="ui-icon-bout">精品</i>
# </h3>
# <p class="ret-works-author" title="佟遥 图：佟遥 文：佟遥">佟遥 图：佟遥 文：佟遥</p>
# <p class="ret-works-tags">
# <a href="/Comic/all/theme/7" target="_blank">玄幻</a>
# <a href="/Comic/all/theme/1" target="_blank">爆笑</a>
# <a href="/Comic/all/theme/14" target="_blank">都市</a>
# <span>人气：<em>162.7亿</em></span>
# </p>
# <p class="ret-works-decs">昼夜颠倒的新时代，勤劳的御史大人们降妖除魔打怪兽的欢乐故事~~在一个蛇精病一样爱好行为艺术的男主和一...</p>
# <a class="ret-works-view ui-btn-pink" href="/Comic/comicInfo/id/519855" target="_blank">开始阅读</a>
# </div>
# </li>
# <li class="ret-search-item clearfix">
# <div class="ret-works-cover">
# <a class="mod-cover-list-thumb mod-cover-effect ui-db" href="/Comic/comicInfo/id/552724" target="_blank" title="猫妖的诱惑">
# <img class="lazy" data-original="https://manhua.qpic.cn/vertical/0/26_11_15_46b8bc032d76eaddfe691f65993a8d76_1501038909539.jpg/420" src="http://ac.gtimg.com/media/images/blank.gif"/>
# <span class="mod-layer-mask">  </span>
# </a>
# <p class="mod-cover-list-updata">
# <a class="mod-cover-list-mask" href="/Comic/comicInfo/id/552724" target="_blank"><span class="mod-cover-list-text">更新至131话</span></a>
# </p>
# </div>
# <div class="ret-works-info">
# <h3 class="ret-works-title clearfix">
# <a href="/Comic/comicInfo/id/552724" target="_blank" title="猫妖的诱惑">猫妖的诱惑</a>
# <i class="ui-icon-sign">签约</i>
# <i class="ui-icon-bout">精品</i>
# </h3>
# <p class="ret-works-author" title="青玉 ">青玉 </p>
# <p class="ret-works-tags">
# <a href="/Comic/all/theme/15" target="_blank">恋爱</a>
# <a href="/Comic/all/theme/7" target="_blank">玄幻</a>
# <a href="/Comic/all/theme/36" target="_blank">唯美</a>
# <span>人气：<em>161.2亿</em></span>
# </p>
# <p class="ret-works-decs">【周三周六更新】精分猫妖带着前世记忆重生，扬言要找前世恋人复仇，但是看到他就好想亲亲扑倒怎么办？！看...</p>
# <a class="ret-works-view ui-btn-pink" href="/Comic/comicInfo/id/552724" target="_blank">开始阅读</a>
# </div>
# </li>
# <li class="ret-search-item clearfix">
# <div class="ret-works-cover">
# <a class="mod-cover-list-thumb mod-cover-effect ui-db" href="/Comic/comicInfo/id/505432" target="_blank" title="火影忍者">
# <img class="lazy" data-original="https://manhua.qpic.cn/vertical/0/21_15_30_e74fc730f5b060f35c6eb0eeb082478f_1498030250417.jpg/420" src="http://ac.gtimg.com/media/images/blank.gif"/>
# <span class="mod-layer-mask">  </span>
# </a>
# <p class="mod-cover-list-updata">
# <a class="mod-cover-list-mask" href="/Comic/comicInfo/id/505432" target="_blank"><span class="mod-cover-list-text">全711话</span></a>
# </p>
# </div>
# <div class="ret-works-info">
# <h3 class="ret-works-title clearfix">
# <a href="/Comic/comicInfo/id/505432" target="_blank" title="火影忍者">火影忍者</a>
# <i class="ui-icon-bout">精品</i>
# <i class="ui-icon-chot">热门</i>
# </h3>
# <p class="ret-works-author" title="岸本齐史 图：岸本齐史 文：岸本齐史">岸本齐史 图：岸本齐史 文：岸本齐史</p>
# <p class="ret-works-tags">
# <a href="/Comic/all/theme/2" target="_blank">热血</a>
# <a href="/Comic/all/theme/34" target="_blank">动作</a>
# <a href="/Comic/all/theme/3" target="_blank">冒险</a>
# <span>人气：<em>153.1亿</em></span>
# </p>
# <p class="ret-works-decs">从小身上封印着邪恶的九尾妖狐，无父无母的主人公鸣人受尽了村里人的冷落但是他却不知道其中的原因，只是拼...</p>
# <a class="ret-works-view ui-btn-pink" href="/Comic/comicInfo/id/505432" target="_blank">开始阅读</a>
# </div>
# </li>
# <li class="ret-search-item clearfix">
# <div class="ret-works-cover">
# <a class="mod-cover-list-thumb mod-cover-effect ui-db" href="/Comic/comicInfo/id/511915" target="_blank" title="中国惊奇先生">
# <img class="lazy" data-original="https://manhua.qpic.cn/vertical/0/17_16_53_938f9aa69728fd462a62074b81f0f3fb.jpg/420" src="http://ac.gtimg.com/media/images/blank.gif"/>
# <span class="mod-layer-mask">  </span>
# </a>
# <p class="mod-cover-list-updata">
# <a class="mod-cover-list-mask" href="/Comic/comicInfo/id/511915" target="_blank"><span class="mod-cover-list-text">更新至693话</span></a>
# </p>
# </div>
# <div class="ret-works-info">
# <h3 class="ret-works-title clearfix">
# <a href="/Comic/comicInfo/id/511915" target="_blank" title="中国惊奇先生">中国惊奇先生</a>
# <i class="ui-icon-sign">签约</i>
# <i class="ui-icon-bout">精品</i>
# </h3>
# <p class="ret-works-author" title="权迎升 图：权迎升 文：权迎升">权迎升 图：权迎升 文：权迎升</p>
# <p class="ret-works-tags">
# <a href="/Comic/all/theme/4" target="_blank">恐怖</a>
# <a href="/Comic/all/theme/35" target="_blank">惊险</a>
# <a href="/Comic/all/theme/1" target="_blank">爆笑</a>
# <span>人气：<em>150.2亿</em></span>
# </p>
# <p class="ret-works-decs">身怀神鬼七杀令的屌丝青年王小二，初涉职场的美女警花李雪，心地善良的痴情小狐狸……漫画每周一三五更新（...</p>
# <a class="ret-works-view ui-btn-pink" href="/Comic/comicInfo/id/511915" target="_blank">开始阅读</a>
# </div>
# </li>
# <li class="ret-search-item clearfix">
# <div class="ret-works-cover">
# <a class="mod-cover-list-thumb mod-cover-effect ui-db" href="/Comic/comicInfo/id/505430" target="_blank" title="航海王">
# <img class="lazy" data-original="https://manhua.qpic.cn/vertical/0/17_16_48_0e28c8aabf48e91d395689b5f6a7689f.jpg/420" src="http://ac.gtimg.com/media/images/blank.gif"/>
# <span class="mod-layer-mask">  </span>
# </a>
# <p class="mod-cover-list-updata">
# <a class="mod-cover-list-mask" href="/Comic/comicInfo/id/505430" target="_blank"><span class="mod-cover-list-text">更新至903话</span></a>
# </p>
# </div>
# <div class="ret-works-info">
# <h3 class="ret-works-title clearfix">
# <a href="/Comic/comicInfo/id/505430" target="_blank" title="航海王">航海王</a>
# <i class="ui-icon-bout">精品</i>
# <i class="ui-icon-chot">热门</i>
# </h3>
# <p class="ret-works-author" title="尾田荣一郎 图：尾田荣一郎 文：尾田荣一郎">尾田荣一郎 图：尾田荣一郎 文：尾田荣一郎</p>
# <p class="ret-works-tags">
# <a href="/Comic/all/theme/2" target="_blank">热血</a>
# <a href="/Comic/all/theme/3" target="_blank">冒险</a>
# <a href="/Comic/all/theme/1" target="_blank">爆笑</a>
# <span>人气：<em>145.9亿</em></span>
# </p>
# <p class="ret-works-decs">作品连载于周刊杂志《周刊少年JUMP》，与日本同步更新，每周周一更新。
# [简介]有一个梦想成为海盗...</p>
# <a class="ret-works-view ui-btn-pink" href="/Comic/comicInfo/id/505430" target="_blank">开始阅读</a>
# </div>
# </li>
# <li class="ret-search-item clearfix">
# <div class="ret-works-cover">
# <a class="mod-cover-list-thumb mod-cover-effect ui-db" href="/Comic/comicInfo/id/531490" target="_blank" title="一人之下">
# <img class="lazy" data-original="https://manhua.qpic.cn/vertical/0/13_14_14_2908dee17c39620a5185ac95767f6583_1497334441884.jpg/420" src="http://ac.gtimg.com/media/images/blank.gif"/>
# <span class="mod-layer-mask">  </span>
# </a>
# <p class="mod-cover-list-updata">
# <a class="mod-cover-list-mask" href="/Comic/comicInfo/id/531490" target="_blank"><span class="mod-cover-list-text">更新至349话</span></a>
# </p>
# </div>
# <div class="ret-works-info">
# <h3 class="ret-works-title clearfix">
# <a href="/Comic/comicInfo/id/531490" target="_blank" title="一人之下">一人之下</a>
# <i class="ui-icon-sign">签约</i>
# <i class="ui-icon-bout">精品</i>
# </h3>
# <p class="ret-works-author" title="动漫堂 图：米二 文：米二">动漫堂 图：米二 文：米二</p>
# <p class="ret-works-tags">
# <a href="/Comic/all/theme/7" target="_blank">玄幻</a>
# <a href="/Comic/all/theme/17" target="_blank">格斗</a>
# <a href="/Comic/all/theme/1" target="_blank">爆笑</a>
# <span>人气：<em>142.9亿</em></span>
# </p>
# <p class="ret-works-decs">大学生张楚岚清明回乡，遭遇神秘少女冯宝宝。素未谋面的冯宝宝却对张楚岚异常熟悉，并将其带去自己打工的快...</p>
# <a class="ret-works-view ui-btn-pink" href="/Comic/comicInfo/id/531490" target="_blank">开始阅读</a>
# </div>
# </li>
# <li class="ret-search-item clearfix">
# <div class="ret-works-cover">
# <a class="mod-cover-list-thumb mod-cover-effect ui-db" href="/Comic/comicInfo/id/525550" target="_blank" title="银之守墓人">
# <img class="lazy" data-original="https://manhua.qpic.cn/vertical/0/08_11_26_70333698a38b7f361e3504c981bbba94_1496892374440.jpg/420" src="http://ac.gtimg.com/media/images/blank.gif"/>
# <span class="mod-layer-mask">  </span>
# </a>
# <p class="mod-cover-list-updata">
# <a class="mod-cover-list-mask" href="/Comic/comicInfo/id/525550" target="_blank"><span class="mod-cover-list-text">更新至414话</span></a>
# </p>
# </div>
# <div class="ret-works-info">
# <h3 class="ret-works-title clearfix">
# <a href="/Comic/comicInfo/id/525550" target="_blank" title="银之守墓人">银之守墓人</a>
# <i class="ui-icon-sign">签约</i>
# <i class="ui-icon-bout">精品</i>
# </h3>
# <p class="ret-works-author" title="零盟 图：月饼 文：闵寻">零盟 图：月饼 文：闵寻</p>
# <p class="ret-works-tags">
# <a href="/Comic/all/theme/7" target="_blank">玄幻</a>
# <a href="/Comic/all/theme/3" target="_blank">冒险</a>
# <a href="/Comic/all/theme/22" target="_blank">竞技</a>
# <span>人气：<em>134.1亿</em></span>
# </p>
# <p class="ret-works-decs">穷苦高中生陆水银是个游戏达人，突然他意外获得5亿遗产却不料全是游戏币，接着心仪的女生被绑架，一连窜神...</p>
# <a class="ret-works-view ui-btn-pink" href="/Comic/comicInfo/id/525550" target="_blank">开始阅读</a>
# </div>
# </li>
# <li class="ret-search-item clearfix">
# <div class="ret-works-cover">
# <a class="mod-cover-list-thumb mod-cover-effect ui-db" href="/Comic/comicInfo/id/518333" target="_blank" title="狐妖小红娘">
# <img class="lazy" data-original="https://manhua.qpic.cn/vertical/0/17_16_12_cd4e6fe51036f100d5f2c1eb1289788e.jpg/420" src="http://ac.gtimg.com/media/images/blank.gif"/>
# <span class="mod-layer-mask">  </span>
# </a>
# <p class="mod-cover-list-updata">
# <a class="mod-cover-list-mask" href="/Comic/comicInfo/id/518333" target="_blank"><span class="mod-cover-list-text">更新至397话</span></a>
# </p>
# </div>
# <div class="ret-works-info">
# <h3 class="ret-works-title clearfix">
# <a href="/Comic/comicInfo/id/518333" target="_blank" title="狐妖小红娘">狐妖小红娘</a>
# <i class="ui-icon-sign">签约</i>
# <i class="ui-icon-bout">精品</i>
# </h3>
# <p class="ret-works-author" title="小新 图：小新 文：小新">小新 图：小新 文：小新</p>
# <p class="ret-works-tags">
# <a href="/Comic/all/theme/7" target="_blank">玄幻</a>
# <a href="/Comic/all/theme/15" target="_blank">恋爱</a>
# <a href="/Comic/all/theme/1" target="_blank">爆笑</a>
# <span>人气：<em>123亿</em></span>
# </p>
# <p class="ret-works-decs">迷糊萝莉小狐妖，正太道士没节操。自古人妖生死恋，千载孽缘一线牵！（注：现在起狐妖每周三、六更新。）</p>
# <a class="ret-works-view ui-btn-pink" href="/Comic/comicInfo/id/518333" target="_blank">开始阅读</a>
# </div>
# </li>
# <li class="ret-search-item clearfix">
# <div class="ret-works-cover">
# <a class="mod-cover-list-thumb mod-cover-effect ui-db" href="/Comic/comicInfo/id/531040" target="_blank" title="斗破苍穹">
# <img class="lazy" data-original="https://manhua.qpic.cn/vertical/0/17_17_06_1208ccae829c75401df329e7140d550e.jpg/420" src="http://ac.gtimg.com/media/images/blank.gif"/>
# <span class="mod-layer-mask">  </span>
# </a>
# <p class="mod-cover-list-updata">
# <a class="mod-cover-list-mask" href="/Comic/comicInfo/id/531040" target="_blank"><span class="mod-cover-list-text">更新至339话</span></a>
# </p>
# </div>
# <div class="ret-works-info">
# <h3 class="ret-works-title clearfix">
# <a href="/Comic/comicInfo/id/531040" target="_blank" title="斗破苍穹">斗破苍穹</a>
# <i class="ui-icon-bout">精品</i>
# <i class="ui-icon-exclusive">独家</i>
# </h3>
# <p class="ret-works-author" title="知音漫客 图：任翔">知音漫客 图：任翔</p>
# <p class="ret-works-tags">
# <a href="/Comic/all/theme/2" target="_blank">热血</a>
# <a href="/Comic/all/theme/6" target="_blank">魔幻</a>
# <a href="/Comic/all/theme/34" target="_blank">动作</a>
# <span>人气：<em>122亿</em></span>
# </p>
# <p class="ret-works-decs">正所谓三十年河东三十年河西，天才少年因忽然失去了天生的灵力，被所有人嘲笑排挤，为了一雪前耻他亲手毁掉...</p>
# <a class="ret-works-view ui-btn-pink" href="/Comic/comicInfo/id/531040" target="_blank">开始阅读</a>
# </div>
# </li>
# </ul>
# <div class="ret-page-wr mod-page" id="pagination2"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- footer -->
# <div class="mod-footer-wr">
# <div class="mod-footer-main-wr">
# <div class="mod-footer-main ui-wm">
# <!-- 二维码 -->
# <ul class="mod-footer-scan ui-ma">
# <li>
# <img alt="腾讯动漫客户端" src="http://ac.gtimg.com/media/images/ac_qr_img.jpg" title="腾讯动漫客户端"/>
# <p style="color:#fff">腾讯动漫客户端</p>
# </li>
# <li>
# <img alt="腾讯动漫微信" src="http://ac.gtimg.com/media/images/ac_wx_img.jpg" title="腾讯动漫微信"/>
# <p style="color:#fff">腾讯动漫微信</p>
# </li>
# </ul>
# <!-- 版权 -->
# <p class="mod-footer-info">
# <a href="http://ac.qq.com/sitemap.html" target="_blank" title="网站地图">网站地图</a>
# <a href="http://ac.qq.com/faq.shtml" target="_blank" title="站内帮助">站内帮助</a>
# <a href="http://support.qq.com/write.shtml?fid=744" target="_blank" title="反馈通道">反馈通道</a>
# <a href="http://weibo.com/u/5203786516" target="_blank">官方微博</a>
# <a href="http://mail.qq.com/cgi-bin/bookcol?colid=109" target="_blank">邮箱推荐</a>
# <a href="http://ac.qq.com/service.shtml" target="_blank">服务协议</a>
# <a href="http://ac.qq.com/copyright.shtml" target="_blank">侵权反馈指引</a>
# <span class="ui-pl10" style="color:#fff">联系方式：<a class="mod-footer-mail" href="mailto:ac_copyright@qq.com">ac_copyright@qq.com</a></span>
# </p>
# <p class="mod-footer-info">Copyright<span class="mod-copyright" style="color:#fff">©</span>1998 - 2018 Tencent. All Rights Reserved</p>
# <p class="mod-footer-info">腾讯公司 版权所有</p>
# </div>
# </div>
# <div class="mod-footer-border"></div>
# </div>
# <div class="mod-side-touch">
# <a class="mod-touch-btn" href="http://m.ac.qq.com" title="触屏版">触屏版</a>
# </div>
# <script src="http://ac.gtimg.com/media/js/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script src="http://ac.gtimg.com/media/js/ac.base.js?v=20170622" type="text/javascript"></script>
# <script src="http://ac.gtimg.com/media/js/tx.func.js" type="text/javascript"></script>
# <script src="http://ac.gtimg.com/media/js/ac.page.comic.all.js?v=20170622" type="text/javascript"></script>
# <script type="text/javascript">
#         var mark = "";
#         var audience = "";
#         var theme = "";
#         var type = "";
#         var finish = "";
#         var state = "";
#         var nation = "";
#         var search = "hot";
#         var tagList = "1#爆笑|2#热血|3#冒险|4#恐怖|5#科幻|6#魔幻|7#玄幻|8#校园|9#悬疑|10#推理|11#萌系|12#穿越|13#后宫|14#都市|15#恋爱|16#武侠|17#格斗|18#战争|19#历史|20#彩虹|21#同人|22#竞技|23#励志|24#百合|25#治愈|26#机甲|27#纯爱|28#美食|29#血腥|30#僵尸|31#恶搞|32#虐心|33#生活|34#动作|35#惊险|36#唯美|37#震撼|38#复仇|39#侦探|40#其它|41#脑洞|42#奇幻|43#宫斗|44#爆笑|45#运动|46#青春|47#穿越|48#灵异|49#古风|50#权谋|51#节操|52#明星|53#暗黑|54#社会|55#浪漫|56#栏目";
#         var copyright = "";
#         var vip = "";
#
#         AC.Page.ComicAll.init();
#
#         $(".mod-top-small-nav").find(":contains('全部作品')").parent().addClass("active");
#     </script>
# <script src="http://ac.gtimg.com/media/js/ac.mod.pagination.js?v=20170622" type="text/javascript"></script>
# <script type="text/javascript">
#     var totalNum = "27746";
#     var pageIndex = "1";
#     var pageSize = "12";
#
#     function changePage(page) {
#         var pageFlag = false;
#         var result = [];
#
#         var href = self.location.href;
#         href = href.replace('//', '^');
#         var params = href.split('/');
#         for (var i = 0; i < params.length; i++) {
#             result.push(params[i]);
#             if (params[i] == 'page') {
#                 pageFlag = true;
#
#                 i++;
#                 result.push(page);
#             }
#         }
#
#         if (!pageFlag) {
#             result.push("page");
#             result.push(page);
#         }
#
#         var newLocation = result.join('/');
#         newLocation = newLocation.replace('^', "//");
#
#         location.replace(newLocation);
#     }
#
#     if ($('#pagination1').length > 0) {
#         var pg1 = new Pagination("pagination1", 1);
#         pg1.onPageChange = changePage;
#         pg1.config(false, false);
#         pg1.show(totalNum, pageIndex, pageSize);
#     }
#
#     if ($('#pagination2').length > 0) {
#         var pg2 = new Pagination("pagination2", 2);
#         pg2.onPageChange = changePage;
#         pg2.config(false, false);
#         pg2.show(totalNum, pageIndex, pageSize);
#     }
# </script> <link href="//ac.gtimg.com/media/css/ac.page.nav.index.css?ver=20180408" rel="stylesheet"/>
# <div class="sidebar-common" id="sidebar-common">
# <!--版块-vip-->
# <div class="side-panel vip-panel vip-panel nav-anm" id="sidebarComPanelVIP">
# <div class="panel-title">我的VIP</div>
# <img class="loading-cat" id="sideComVipLoading" src="//ac.gtimg.com/media/images/navright/loading_cat.gif"/>
# <div id="sidebarComVipData" style="display: none;">
# <script id="sidebarComScriptVip" type="text/html">
#                 <div class="panel-content <% if(vip.state==2){ %>vip<% } else if(vip.state==1) { if(!vip.expiredTime){ %> vip-not <%}else{%> vip vip-due <% }}%>">
#                     <a class="panel-avatar-wrap" href="/Home/index" title="个人中心" target="_blank">
#                         <span class="panel-crown" <% if(vip.state !=2){ %>style="display: none;"<% } %>></span>
#                         <img src="<%=avatar%>" alt="头像"/>
#                     </a>
#                     <a href="/Home" title="个人中心" class="panel-nickname" target="_blank"><%=nick%></a>
#
#                     <% if(vip.expiredTime){ %>
#                     <a class="vip-state-wrap clearfix" href="/Charge" title="我的VIP" target="_blank" onclick='pgvSendClick({hottag:"AC.NAVRIGHT.VIP.MYVIP"});'><i></i><span>我的VIP<%</span></a>
#                     <% } else { %>
#                     <a class="vip-state-wrap clearfix mod-cd" href="javascript:void(0)" title="我的VIP" target="_blank"><i></i><span>你是非VIP：</span></a>
#                     <% } %>
#
#                     <div class="vip-wrap">
#                         <ul class="personal-list">
#                             <li class="clearfix ui-pr">
#                                 <span class="personal-item-icon icon-coupon"></span><span
#                                     class="personal-item-title">我的点券</span><span
#                                     class="personal-item-num">666</span>
#                             </li>
#                             <li class="clearfix">
#                                 <span class="personal-item-icon icon-readpoint"></span><span
#                                     class="personal-item-title">付费动漫</span><span
#                                     class="personal-item-num">8折</span>
#                             </li>
#                             <li class="clearfix">
#                                 <span class="personal-item-icon icon-ticket"></span><span
#                                     class="personal-item-title">我的月票</span><span
#                                     class="personal-item-num"><%=monthTicket%></span>
#                             </li>
#                         </ul>
#                         <a href="javascript:void(0)" title="续费动漫VIP" class="pay-btn">续费动漫VIP</a>
#                     </div>
#
#                     <div class="not-vip-wrap">
#                         <p class="title">动漫VIP为您提供</p>
#                         <ul class="panel-vip-privilege clearfix">
#                             <li class="panel-vip-privilege-comic">
#                                 <i></i>
#                                 漫画特权
#                             </li>
#                             <li class="panel-vip-privilege-interact">
#                                 <i></i>
#                                 互动特权
#                             </li>
#                             <li class="panel-vip-privilege-decorate">
#                                 <i></i>
#                                 装扮特权
#                             </li>
#                             <li class="panel-vip-privilege-game">
#                                 <i></i>
#                                 游戏特权
#                             </li>
#                         </ul>
#                         <a href="/Charge" title="查看所有动漫VIP特权" class="panel-vip-privilege-more"
#                            target="_blank" onclick='pgvSendClick({hottag:"AC.NAVRIGHT.VIP.MYVIP"});'>查看所有动漫VIP特权</a>
#                         <a href="javascript:void(0)" title="<%
#                             if(vip.state==2){ %>续费动漫VIP<% } else
#                             if(vip.state==1) { %>开通动漫VIP<% } %>" class="pay-btn"><%
#                             if(vip.state==2){ %>续费动漫VIP<% } else
#                             if(vip.state==1) { %>开通动漫VIP<% } %></a>
#
#                         <p class="tip">首次开通VIP额外赠送一个月哦</p>
#                     </div>
#                 </div>
#             </script>
# </div>
# <a alt="关闭" class="personal-panel-close panel-close" data-type="panel-close" href="javascript:void(0)" id="sidebarComPanelVipClose"></a>
# </div>
# <!--版块-我-->
# <div class="side-panel personal-panel nav-anm" id="sidebarComPanelMe">
# <div class="panel-title">个人中心</div>
# <img class="loading-cat" id="sideComMeLoading" src="//ac.gtimg.com/media/images/navright/loading_cat.gif"/><div id="sidebarComMeData" style="display: none;">
# <script id="sidebarComScriptMe" type="text/html">
#                 <div class="panel-content">
#                     <a class="panel-avatar-wrap" href="/Home/index" title="个人中心" target="_blank">
#                         <span class="panel-crown" <% if(vip.state !=2){ %>style="display: none;"<% } %>></span>
#                         <img src="<%=avatar%>" alt="头像" id="sidebarComPanelMeAvatar"/>
#                     </a>
#                     <a href="/Home" title="个人中心" class="panel-nickname" target="_blank"><%=nick%></a>
#                     <ul class="personal-list">
#                         <li class="clearfix ui-pr">
#                             <span class="personal-item-icon icon-coupon"></span><span class="personal-item-title">我的点券</span><span class="personal-item-num"><%=coupons%></span>
#                             <a href="/VIP/pay" title="充值" class="personal-item-pay" target="_blank" onclick='pgvSendClick({hottag:"AC.NAVRIGHT.USER.PAY"});'>充值</a>
#                         </li>
#                         <li class="clearfix">
#                             <span class="personal-item-icon icon-readpoint"></span><span
#                                 class="personal-item-title">我的阅点</span><span
#                                 class="personal-item-num"><%=readPoint%></span>
#                         </li>
#                         <li class="clearfix">
#                             <span class="personal-item-icon icon-ticket"></span><span
#                                 class="personal-item-title">我的月票</span><span
#                                 class="personal-item-num"><%=monthTicket%></span>
#                         </li>
#                     </ul>
#                     <div class="line"></div>
#                     <a class="personal-honer-title personal-news-title" title="我的消息" target="_blank" href="/Home/inbox" onclick='pgvSendClick({hottag:"AC.NAVRIGHT.USER.MSG"});'>我的消息<span class="personal-honer-num" id="sidebarComMeNews">&nbsp;&nbsp;<%=news%></span></a>
#
#                     <!--资产升级-->
#                     <% if(isShowAsset==2){ %>
#                     <a href="javascript:void(0)" class="my-property-update">资产升级</a>
#                     <% } %>
#
#                     <div class="line personal-honer-line"></div>
#
#                     <% if(vip.state==2){ %>
#                     <a class="vip-state-wrap clearfix" href="/Home/index" title="个人中心" target="_blank" onclick='pgvSendClick({hottag:"AC.NAVRIGHT.VIP.MYVIP"});'><i></i><span>我的VIP<%</span></a>
#                     <p class="personal-vip-date"><span class="personal-item-title">到期时间</span><span class="personal-item-num"><%=vip.expiredTime%></span></p>
#                     <a class="personal-vip-comic" href="//ac.qq.com/Comic/all/search/time/vip/3/page/1" target="_blank" title="VIP免费漫画" onclick='pgvSendClick({hottag:"AC.NAVRIGHT.VIP.COMIC"});'>VIP免费漫画</a>
#                     <div class="line personal-vip-line"></div>
#                     <% } %>
#
#                     <h4 class="personal-honer-title">我的勋章<span class="personal-honer-num" id="sidebarComMeHoner"><%if(medal.monthTicket+medal.vip+medal.award>0){%><%=medal.monthTicket+medal.vip+medal.award%><%}else{%>0<%}%></span></h4>
#
#                     <div id="" style="display: none;">
#                         <div class="panel-none"></div>
#                         <p class="panel-none-txt">勋章都没一枚，醉醉哒~</p>
#                     </div>
#                     <ul class="personal-honer-list clearfix">
#                         <% if(medal.vip > 0) { %>
#                         <%for(var i = 1; i <= medal.vip; i++) { %>
#                         <li class="mod-honer-small mod-pay-small-<%=i%>"></li>
#                         <% } %>
#                         <% } %>
#                         <% if(medal.award > 0) { %>
#                         <%for(var i = 1; i <= medal.award; i++) { %>
#                         <li class="mod-plays-honer-big mod-plays-big-<%=i%>"></li>
#                         <% } %>
#                         <% } %>
#                         <% if(medal.monthTicket > 0) { %>
#                         <%for(var i = 1; i <= medal.monthTicket; i++) { %>
#                         <li class="mod-honer-small mod-moon-small-<%=i%>"></li>
#                         <% } %>
#                         <% } %>
#                     </ul>
#                     <div class="personal-logout-wrap clearfix">
#                         <a href="javascript:void(0)" title="退出" id="sidebarComPanelMeLogout">退出</a>
#                     </div>
#                 </div>
#             </script>
# </div>
# <a alt="关闭" class="personal-panel-close panel-close" data-type="panel-close" href="javascript:void(0)" id="sidebarComPanelMeClose"></a>
# </div>
# <!--版块-历史-->
# <div class="side-panel history-panel nav-anm" id="sidebarComPanelHistory">
# <div class="panel-title">我看过的</div>
# <img class="loading-cat" id="sideComHisLoading" src="//ac.gtimg.com/media/images/navright/loading_cat.gif"/>
# <div class="mod-h100" id="sidebarComHistoryData" style="display: none;">
# <script id="sidebarComScriptHistory" type="text/html">
#                 <% if(localList) { %>
#                 <div class="panel-tip localHisTip">登录后可同步云端阅读历史<a href="javascript:AC.NavRight.showLogin();" title="点击登录">点击登录</a></div>
#                 <div class="scroll-me" data-scroll="navComScrollHistory" <%if(localList.length<=0){%>style="display:none"<%}%> >
#
#                 <div class="relative">
#                     <div class="my-list scroll-list-wrap panel-collect-scroll" id="navComHisScrollWrap">
#                         <div class="my-data scroll-list moved panel-history-list panel-local-history" id="navComHisScrollList">
#                             <a href="javascript:void(0)" title="清除记录" class="panel-history-clear" id="sidebarComHisClear" data-type="local-clear">清除记录</a>
#
#                             <% for(var i = 0, len = localList.length; i < len; i++) { %>
#                             <div class="panel-history-item panel-local-history <%if(i==0){%>bdt0<%}%>" data-type="<% if(localList[i].updateFlag) { %>update<% } %>">
#                                 <span class="panel-history-underlayer"></span>
#                                 <% if(localList[i].updateFlag && localList[i].lateSeqNo != localList[i].viewSeqNo) { %><sup
#                                     class="dot update-dot"></sup><%
#                                 } %>
#                                 <a href="/Comic/ComicInfo/id/<%=localList[i].id%>"
#                                    title="<%=localList[i].title%>" target="_blank" class="panel-comic-item-title"
#                                    data-type="comic-detail">[漫画]<%=localList[i].title.slice(0,
#                                     8)%></a>
#                                 <a href="/ComicView/index/id/<%=localList[i].id%>/seqno/<%=localList[i].viewSeqNo%>"
#                                    title="第<%=localList[i].viewSeqNo%>话" class="panel-comic-item-p" target="_blank"
#                                    data-type="comic-browse">已看<span
#                                         class="collect-read"><%=localList[i].viewSeqNo%></span>话</a>
#                                 <% if(localList[i].finishState == 1) { %>
#                                 <a href="/ComicView/index/id/<%=localList[i].id%>/seqno/<%=localList[i].lateSeqNo%>"
#                                    title="第<%=localList[i].lateSeqNo%>话"
#                                    class="panel-comic-item-p panel-collect-update"
#                                    target="_blank">更新至<span
#                                         class="collect-update"><%=localList[i].lateSeqNo%></span>话</a>
#                                 <% } %>
#                                 <% if(localList[i].finishState == 2) { %>
#                                 <a href="/ComicView/index/id/<%=localList[i].id%>/seqno/<%=localList[i].lateSeqNo%>"
#                                    title="第<%=localList[i].lateSeqNo%>话"
#                                    class="panel-comic-item-p panel-collect-update"
#                                    target="_blank">全<span class="collect-update"><%=localList[i].lateSeqNo%></span>话</a>
#                                 <% } %>
#                                 <% if(localList[i].viewSeqNo != localList[i].lateSeqNo) { %>
#                                 <a href="/ComicView/index/id/<%=localList[i].id%>/seqno/<%=localList[i].nextSeqNo%>"
#                                    title="第<%=localList[i].nextSeqNo%>集"
#                                    class="panel-comic-item-p mod-tdu panel-comic-continue"
#                                    target="_blank" data-type="comic-browse">继续观看</a>
#                                 <% } %>
#                                 <a href="javascript:void(0)" class="panel-history-delete delete-local"
#                                    data-id="<%=localList[i].id%>"></a>
#                             </div>
#                             <% } %>
#                         </div>
#                     </div>
#                     <div class="scroll-bg" id="navComHisScrollBg">
#                         <div class="scroll-block" id="navComHisscrollBlock"></div>
#                     </div>
#                 </div>
#                 </div>
#                 <% } else if(list.length > 0) { %>
#                 <div class="scroll-me" data-scroll="navComScrollHistory" <%if(list.length<=0){%>style="display:none"<%}%> >
#
#                 <div class="relative">
#                     <div class="my-list scroll-list-wrap panel-collect-scroll" id="navComHisScrollWrap">
#                         <div class="my-data scroll-list moved panel-history-list" id="navComHisScrollList">
#                             <i class="time-line-left" id="sidebarComTimeLine"></i>
#                             <a href="javascript:void(0)" title="清除记录" class="panel-history-clear"
#                                id="sidebarComHisClear" data-type="cloud-clear">清除记录</a>
#
#                             <% if(devide.today > 0) { %>
#                             <h3 class="mgt0 history-title-time"><i class="dot"></i>今日</h3>
#                             <% for(var i = 0, len = devide.today; i < len; i++) { %>
#                             <div class="panel-history-item <%if(i==0){%>bdt0<%}%>"
#                                  data-type="<% if(list[i].updateFlag) { %>update<% } %>">
#                                 <span class="panel-history-underlayer"></span>
#                                 <% if(list[i].isAnimation) { %>
#                                 <% if(list[i].updateFlag && list[i].lateSeqNo != list[i].viewSeqNo) { %><sup
#                                     class="dot update-dot"></sup><%
#                                 } %>
#                                 <a href="/Cartoon/detail/id/<%=list[i].id%>/sid/1"
#                                    title="<%=list[i].title%>" target="_blank" class="panel-comic-item-title"
#                                    data-type="go-anm">[动画]<%=list[i].title.slice(0,
#                                     8)%></a>
#                                 <a href="/Cartoon/detail/id/<%=list[i].id%>/sid/<%=list[i].viewSeqNo%>"
#                                    title="第<%=list[i].viewSeqNo%>集" class="panel-comic-item-p" target="_blank"
#                                    data-type="go-anm">已看<%=list[i].viewSeqNo%>集</a>
#                                 <a href="/Cartoon/detail/id/<%=list[i].id%>/sid/<%=list[i].viewSeqNo%>"
#                                    title="第<%=list[i].viewSeqNo%>集"
#                                    class="panel-comic-item-p mod-tdu panel-comic-continue"
#                                    target="_blank" data-type="go-anm">继续观看</a>
#                                 <a href="javascript:void(0)" class="panel-history-delete delete-anm"
#                                    data-id="<%=list[i].id%>"></a>
#
#                                 <% } else { %>
#                                 <% if(list[i].updateFlag && list[i].lateSeqNo != list[i].viewSeqNo) { %><sup
#                                     class="dot update-dot"></sup><%
#                                 } %>
#                                 <a href="/Comic/ComicInfo/id/<%=list[i].id%>"
#                                    title="<%=list[i].title%>" target="_blank" class="panel-comic-item-title"
#                                    data-type="comic-detail">[漫画]<%=list[i].title.slice(0,
#                                     8)%></a>
#                                 <a href="/ComicView/index/id/<%=list[i].id%>/seqno/<%=list[i].viewSeqNo%>"
#                                    title="第<%=list[i].viewSeqNo%>话" class="panel-comic-item-p" target="_blank"
#                                    data-type="comic-browse">已看<span class="collect-read"><%=list[i].viewSeqNo%></span>话</a>
#                                 <% if(list[i].finishState == 1) { %>
#                                 <a href="/ComicView/index/id/<%=list[i].id%>/seqno/<%=list[i].lateSeqNo%>"
#                                    title="第<%=list[i].lateSeqNo%>话" class="panel-comic-item-p panel-collect-update"
#                                    target="_blank">更新至<span class="collect-update"><%=list[i].lateSeqNo%></span>话</a>
#                                 <% } %>
#                                 <% if(list[i].finishState == 2) { %>
#                                 <a href="/ComicView/index/id/<%=list[i].id%>/seqno/<%=list[i].lateSeqNo%>"
#                                    title="第<%=list[i].lateSeqNo%>话" class="panel-comic-item-p panel-collect-update"
#                                    target="_blank">全<span class="collect-update"><%=list[i].lateSeqNo%></span>话</a>
#                                 <% } %>
#                                 <% if(list[i].viewSeqNo != list[i].lateSeqNo) { %>
#                                 <a href="/ComicView/index/id/<%=list[i].id%>/seqno/<%=list[i].nextSeqNo%>"
#                                    title="第<%=list[i].nextSeqNo%>集"
#                                    class="panel-comic-item-p mod-tdu panel-comic-continue"
#                                    target="_blank" data-type="comic-browse">继续观看</a>
#                                 <% } %>
#                                 <a href="javascript:void(0)"
#                                    class="panel-history-collect <% if(list[i].collected) { %> collected <% } %>"
#                                    title="<% if(list[i].collected) { %> 已收藏 <% }else { %>收藏<% } %>"
#                                    data-type="<% if(list[i].collected) { %>collect-delete<% } else{ %>collect-btn<% } %>"></a>
#                                 <a href="javascript:void(0)" class="panel-history-delete delete-comic"
#                                    data-id="<%=list[i].id%>"></a>
#                                 <% } %>
#                             </div>
#                             <% } %>
#                             <% } %>
#
#                             <% if(devide.week > 0) { %>
#                             <h3 class="<%if(devide.today == 0){%>mgt0<%}%> history-title-time"><i class="dot"></i>一周之内
#                             </h3>
#                             <% for(var i = devide.today, len = devide.week + devide.today; i < len;
#                             i++) { %>
#                             <div class="panel-history-item <%if(i==devide.today){%>bdt0<%}%>" data-type="<% if(list[i].updateFlag) { %>update<% } %>">
#                                 <span class="panel-history-underlayer"></span>
#                                 <% if(list[i].isAnimation) { %>
#                                 <% if(list[i].updateFlag && list[i].lateSeqNo != list[i].viewSeqNo) { %><sup
#                                     class="dot update-dot"></sup><%
#                                 } %>
#                                 <a href="/Cartoon/detail/id/<%=list[i].id%>/sid/1"
#                                    title="<%=list[i].title%>" target="_blank" class="panel-comic-item-title"
#                                    data-type="go-anm">[动画]<%=list[i].title.slice(0,
#                                     8)%></a>
#                                 <a href="/Cartoon/detail/id/<%=list[i].id%>/sid/<%=list[i].viewSeqNo%>"
# ...
#                                 <i
#                                         class="dot"></i>更早</h3>
#                             <% for(var i = devide.today + devide.week, len = list.length; i < len; i++) { %>
#                             <div class="panel-history-item <%if(i==devide.today + devide.week){%>bdt0<%}%>"
#                                  data-type="<% if(list[i].updateFlag) { %>update<% } %>">
#                                 <span class="panel-history-underlayer"></span>
#                                 <% if(list[i].isAnimation) { %>
#                                 <% if(list[i].updateFlag && list[i].lateSeqNo != list[i].viewSeqNo) { %><sup
#                                     class="dot update-dot"></sup><%
#                                 } %>
#                                 <a href="/Cartoon/detail/id/<%=list[i].id%>/sid/1"
#                                    title="<%=list[i].title%>" target="_blank" class="panel-comic-item-title"
#                                    data-type="go-anm">[动画]<%=list[i].title.slice(0,
#                                     8)%></a>
#                                 <a href="/Cartoon/detail/id/<%=list[i].id%>/sid/<%=list[i].viewSeqNo%>"
#                                    title="第<%=list[i].viewSeqNo%>集" class="panel-comic-item-p" target="_blank"
#                                    data-type="go-anm">已看<%=list[i].viewSeqNo%>集</a>
#                                 <a href="/Cartoon/detail/id/<%=list[i].id%>/sid/<%=list[i].viewSeqNo%>"
#                                    title="第<%=list[i].viewSeqNo%>集"
#                                    class="panel-comic-item-p mod-tdu panel-comic-continue"
#                                    target="_blank" data-type="go-anm">继续观看</a>
#                                 <a href="javascript:void(0)" class="panel-history-delete delete-anm"
#                                    data-id="<%=list[i].id%>"></a>
#
#                                 <% } else { %>
#                                 <% if(list[i].updateFlag && list[i].lateSeqNo != list[i].viewSeqNo) { %><sup
#                                     class="dot update-dot"></sup><%
#                                 } %>
#                                 <a href="/Comic/ComicInfo/id/<%=list[i].id%>"
#                                    title="<%=list[i].title%>" target="_blank" class="panel-comic-item-title"
#                                    data-type="comic-detail">[漫画]<%=list[i].title.slice(0,
#                                     8)%></a>
#                                 <a href="/ComicView/index/id/<%=list[i].id%>/seqno/<%=list[i].viewSeqNo%>"
#                                    title="第<%=list[i].viewSeqNo%>话" class="panel-comic-item-p" target="_blank"
#                                    data-type="comic-browse">已看<span
#                                         class="collect-read"><%=list[i].viewSeqNo%></span>话</a>
#                                 <% if(list[i].finishState == 1) { %>
#                                 <a href="/ComicView/index/id/<%=list[i].id%>/seqno/<%=list[i].lateSeqNo%>"
#                                    title="第<%=list[i].lateSeqNo%>话" class="panel-comic-item-p panel-collect-update"
#                                    target="_blank">更新至<span class="collect-update"><%=list[i].lateSeqNo%></span>话</a>
#                                 <% } %>
#                                 <% if(list[i].finishState == 2) { %>
#                                 <a href="/ComicView/index/id/<%=list[i].id%>/seqno/<%=list[i].lateSeqNo%>"
#                                    title="第<%=list[i].lateSeqNo%>话" class="panel-comic-item-p" target="_blank">全<%=list[i].lateSeqNo%>话</a>
#                                 <% } %>
#                                 <% if(list[i].viewSeqNo != list[i].lateSeqNo) { %>
#                                 <a href="/ComicView/index/id/<%=list[i].id%>/seqno/<%=list[i].nextSeqNo%>"
#                                    title="第<%=list[i].nextSeqNo%>集"
#                                    class="panel-comic-item-p mod-tdu panel-comic-continue"
#                                    target="_blank" data-type="comic-browse">继续观看</a>
#
#                                 <% } %>
#                                 <a href="javascript:void(0)"
#                                    class="panel-history-collect <% if(list[i].collected) { %> collected <% } %>"
#                                    title="<% if(list[i].collected) { %> 已收藏 <% }else { %>收藏<% } %>"
#                                    data-type="<% if(list[i].collected) { %>collect-delete<% } else{ %>collect-btn<% } %>"></a>
#                                 <a href="javascript:void(0)" class="panel-history-delete delete-comic"
#                                    data-id="<%=list[i].id%>"></a>
#                                 <% } %>
#                             </div>
#                             <% } %>
#                             <% } %>
#                             <p class="bottom" id="sideComHistoryBottom" style="display: none;"><i></i><span>到底啦！</span>
#                             </p>
#                         </div>
#                     </div>
#                     <div class="scroll-bg" id="navComHisScrollBg">
#                         <div class="scroll-block" id="navComHisscrollBlock"></div>
#                     </div>
#                 </div>
#                 </div>
#                 <% } %>
#             </script>
# </div>
# <div class="mod-h100" id="sidebarComRankData" style="display: none">
# <script id="sidebarComScriptRank" type="text/html">
#                 <div class="panel-tip">听说，看过下面内容的银会变漂</div>
#                 <ul class="panel-comic-list">
#                     <% for(var i = 0; i < 5; i++) { %>
#                     <li class="<% if(i==0){%>bdt0<%}%> clearfix">
#                         <a href="/Comic/comicInfo/id/<%=rankList[i].id%>"
#                            title="<%=rankList[i].title.slice(0, 8)%>" class="panel-comic-cover" target="_blank"
#                            onclick='pgvSendClick({hottag:"AC.NAVRIGHT.HISTORY.COMICDETAIL"});'><img
#                                 class="" src="<%=rankList[i].coverUrl%>"
#                                 alt="<%=rankList[i].title%>"></a>
#
#                         <div class="panel-comic-item-cont">
#                             <a href="/Comic/comicInfo/id/<%=rankList[i].id%>"
#                                class="panel-comic-item-title" title="<%=rankList[i].title.slice(0, 8)%>"
#                                target="_blank" onclick='pgvSendClick({hottag:"AC.NAVRIGHT.HISTORY.COMICDETAIL"});'><%=rankList[i].title.slice(0,
#                                 8)%></a>
#                             <a href="/ComicView/index/id/<%=rankList[i].id%>/seqno/<%=rankList[i].lateSeqNo%>"
#                                target="_blank" class="panel-comic-item-p" title="第<%=rankList[i].lateSeqNo%>话">更新至<span
#                                     class="collect-update"
#                                     onclick='pgvSendClick({hottag:"AC.NAVRIGHT.HISTORY.COMICBROWSE"});'><%=rankList[i].lateSeqNo%></span>话</a>
#                             <a href="/ComicView/index/id/<%=rankList[i].id%>/seqno/1" target="_blank"
#                                class="panel-comic-item-p" title="第1话"
#                                onclick='pgvSendClick({hottag:"AC.NAVRIGHT.HISTORY.COMICBROWSE"});'>开始阅读</a>
#                         </div>
#                     </li>
#                     <% } %>
#                 </ul>
#             </script>
# </div>
# <a alt="关闭" class="panel-close" data-type="panel-close" href="javascript:void(0)" id="sidebarComPanelHistoryClose"></a>
# </div>
# <!--版块-收藏-->
# <div class="side-panel collect-panel nav-anm" id="sidebarComPanelCollect">
# <div class="panel-title">我的收藏</div>
# <img class="loading-cat" id="sideComColLoading" src="//ac.gtimg.com/media/images/navright/loading_cat.gif"/>
# <div id="sidebarComCollectData" style="display: none;">
# <script id="sidebarComScriptCollect" type="text/html">
#                 <% if(data.length > 0) { %>
#                 <div></div>
#                 <div class="panel-tip">收藏<%=data.length%>部，更新<span id="sidebarComColUpdate"><%=updateLen%></span>部</div>
#                 <!--<a href="javascript:void(0)" title="全部标记为已读" class="panel-collect-read"-->
#                 <!--id="sidebarComColRead">全部标记为已读</a>-->
#                 <div class="scroll-me panel-collect-scroll-wrap" data-scroll="navComScrollCollect">
#                     <div class="relative">
#                         <div class="my-list scroll-list-wrap panel-collect-scroll" id="navComColScrollWrap">
#                             <ul class="my-data scroll-list moved panel-comic-list" id="navComColScrollList">
#                                 <% var collectLen = data.length > 20 ? 20 : data.length;for (var i = 0; i < collectLen;
#                                 i++) { %>
#                                 <li class="<%if(i==0){%>bdt0 <%}%>clearfix">
#                                     <% if(data[i].updateFlag) { %>
#                                     <sup class="dot update-dot"></sup>
#                                     <% } %>
#                                     <a href="/Comic/comicInfo/id/<%=data[i].id%>" target="_blank"
#                                        class="panel-comic-cover" title="<%=data[i].title%>"
#                                        data-type="comic-detail"><img class=""
#                                                                      src="<%=data[i].coverUrl%>"
#                                                                      alt="<%=data[i].title%>"/></a>
#
#                                     <div class="panel-comic-item-cont"
#                                          data-type="<% if(data[i].updateFlag) { %>update<% } %>">
#                                         <a href="/Comic/comicInfo/id/<%=data[i].id%>"
#                                            target="_blank"
#                                            class="panel-comic-item-title" title="<%=data[i].title%>"
#                                            data-type="comic-detail"><%=data[i].title.slice(0,
#                                             8)%></a>
#                                         <% if(data[i].viewSeqNo == 0) { %>
#                                         <a href="/ComicView/index/id/<%=data[i].id%>/seqno/1"
#                                            target="_blank"
#                                            class="panel-comic-item-p" title="第1话" data-type="comic-browse">已看<span
#                                                 class="collect-read">1</span>话</a>
#                                         <% }else { %>
#                                         <a href="/ComicView/index/id/<%=data[i].id%>/seqno/<%=data[i].viewSeqNo%>"
#                                            target="_blank" class="panel-comic-item-p"
#                                            title="第<%=data[i].viewSeqNo%>话" data-type="comic-browse">已看<span
#                                                 class="collect-read"><%=data[i].viewSeqNo%></span>话</a>
#                                         <% } %>
#                                         <a href="/ComicView/index/id/<%=data[i].id%>/seqno/<%=data[i].lateSeqNo%>"
#                                            target="_blank" class="panel-comic-item-p panel-collect-update"
#                                            title="第<%=data[i].lateSeqNo%>话">更新至<span class="collect-update"><%=data[i].lateSeqNo%></span>话</a>
#                                     </div>
#                                 </li>
#                                 <% } %>
#                                 <a class="more-btn" target="_blank" id="sidebarComColMore"
#                                    href="/Home/bookshelf"
#                                    title="我的书架">我的书架</a>
#                             </ul>
#                         </div>
#                         <div class="scroll-bg" id="navComColScrollBg">
#                             <div class="scroll-block" id="navComColscrollBlock"></div>
#                         </div>
#                     </div>
#                 </div>
#                 <% } else { %>
#                 <div class="panel-tip">你还没收藏任何作品哦</div>
#                 <div style="">
#                     <div class="panel-none"></div>
#                     <p class="panel-none-txt">和我去二次元世界看看吧~</p>
#                 </div>
#                 <% } %>
#             </script>
# </div>
# <a alt="关闭" class="panel-close" data-type="panel-close" href="javascript:void(0)" id="sidebarComPanelCollectClose"></a>
# </div>
# <div class="sidebar-tab" id="sidebarComTab">
# <div class="tab-item tab-avatar">
# <a href="javascript:void(0)" id="sidebarComTabMe" title="我">
# <img alt="" class="avatar" src="//ac.gtimg.com/media/images/top_face_no_bg.jpg"/>
# </a>
# </div>
# <div class="tab-item tab-history">
# <a href="javascript:void(0)" id="sidebarComTabHistory" title="历史">
# <span class="tab-icon history-icon"></span>
# <p class="tab-txt">历史</p>
# <!--<sup class="dot update-dot"></sup>-->
# </a>
# </div>
# <div class="tab-item tab-collect">
# <a href="javascript:void(0)" id="sidebarComTabCollect" title="收藏">
# <span class="tab-icon collect-icon"></span>
# <p class="tab-txt">收藏</p>
# <sup class="dot update-dot" id="sidebarComColDotLen" style="display: none;">
# <!--<i class="left"></i><i class="center"></i><i class="right"></i><span></span>-->
# </sup>
# </a>
# </div>
# <div class="tab-item tab-qrCode" id="sideComCodeWrap">
# <a href="javascript:void(0)" title="二维码">
# <span class="tab-icon qrCode-icon" id="sidebarComCode"></span>
# </a>
# <div class="qrCode-wrap" id="sideComCodeImg" style="display: none;">
# <img alt="二维码" src="//ac.gtimg.com/media/images/navright/qrCode.png"/>
# <p class="txt-1">用APP看漫画</p>
# <p class="txt-2">速领手办公仔</p>
# </div>
# </div>
# <div class="tab-item tab-feedback">
# <!-- 老的反馈系统，切到aisee sharingchen@2018.4.8 <a href="//support.qq.com/write.shtml?fid=744" target="_blank" title="反馈"> -->
# <span class="tab-icon feedback-icon"></span>
# <p class="tab-txt hidden-txt">反馈</p>
# </div></div></div></body></html>
#
# <div class="tab-item tab-top" id="sidebarComTabTop" style="display: none;">
# <a href="javascript:void(0)" title="TOP">
# <span class="tab-icon top-icon"></span>
# <p class="tab-txt top-txt">TOP</p>
# </a>
# </div>
#
# <div class="pop-box" id="sideComPopBox" style="display: none;">
# <h3>确定要清除所有看过的漫画君吗？</h3>
# <p>清除后就再也找不回来啦！</p>
# <div class="btn-wrap">
# <a class="confirm-btn" href="javascript:void(0)">确定</a>
# <a class="cancel-btn" href="javascript:void(0)">取消</a>
# </div>
# </div>
# <div class="update-property-overlay" id="update-property-overlay">
# <div class="update-box" id="update-box">
# <h3 class="update-title">新模式资产大升级</h3>
# <div class="update-info"></div>
# <div class="vip-box" id="vip-box">
# <span class="vip-before-num" id="vip-before-num">0</span>
# <span class="vip-text">VIP有效时间</span>
# <span class="vip-info"></span>
# <span class="vip-after-num" id="vip-after-num">0</span>
# <span class="vip-text">VIP有效时间</span>
# </div>
# <div class="read-bags-box">
# <span class="rb-num" id="rb-num">0</span>
# <span class="rb-text">阅读包</span>
# <span class="rb-info"></span>
# <span class="rb-new-num" id="rb-new-num">0</span>
# <span class="rb-new-text">点券</span>
# </div>
# <div class="read-point-box">
# <span class="rp-num" id="rp-num">0</span>
# <span class="rp-text">阅点</span>
# <span class="rp-info"></span>
# <span class="rp-num-new" id="rp-num-new">0</span>
# <span class="rp-text">阅点</span>
# </div>
# <div id="tks-vip-send">感谢VIP大大的支持,特别赠送<span id="vip-send-red">200</span>阅点</div>
# <a class="btn-property-update" href="javascript:;" id="btn-property-update">立即升级</a>
# </div>
# </div>
#
# <div id="sideComSmallHeart"></div>
# <!-- aisee反馈 -->
# <div class="aiseeBox pc" id="pcAiseeBox">
# <div class="aiseeHeader">
# <div class="aiseeBack">←</div>
# <div class="aiseeNav">
# <span class="aiseeNavItem active" id="aiseeNavSubmit">提交反馈</span>
# <span class="aiseeNavItem" id="aiseeNavFeedback">反馈历史</span>
# </div>
# <div class="aiseeClose">Χ</div>
# </div>
# <iframe class="aiseeFrame" frameborder="0" src=""></iframe>
# </div>
# <script charset="utf-8" src="//imgcache.qq.com/bossweb/ipay/js/api/cashier.js" type="text/javascript"></script>
# <script src="//ac.gtimg.com/media/js/ac.page.nav.index.js?v=20180413"></script>

# %%
import mechanicalsoup
browser = mechanicalsoup.StatefulBrowser()

# %%
import requests
import re
for pages_num in range(1,2) :
    params = {
        'search.page' : pages_num,
        }
    list_url = 'http://ac.qq.com/Comic/all/search/hot/page/' + str(pages_num)
    soup = browser.open(list_url).soup

    for tag in soup.select('div.ret-works-info'):
        name = tag.select('h3.ret-works-title.clearfix a')[0].text
        people = tag.select('p.ret-works-tags span em')[0].text
        book_url = urljoin(list_url, tag.find('a')['href'])
        book_soup = browser.open(book_url).soup
        print(name + "◎" ,people+  "◎", book_url+  " ◎", end="")
        try:
            body = book_soup.select('.works-intro-short')[0].text
            body_1 = re.sub(r'^\s+','',body)
            body_2 = re.sub('\n',' ',body_1)
            body_3 = " ".join(body_2.split())
            print(body_3+ "◎", end="")
        except IndexError as e:
            print(e, "◎", end="")
        a = 0
        while a < len(tag.select('p.ret-works-tags a')) :
            n = len(tag.select('p.ret-works-tags a'))
            print(tag.select('p.ret-works-tags a')[a].text, "◎",end='')
            a = a+1
            if a == n:
                break
        print()
# Out:
# 通灵妃◎ 214.1亿◎ http://ac.qq.com/Comic/comicInfo/id/540627 ◎【每周四，周日更新】丞相府大小姐千云兮自小身负异能，被视为不详之人养在灵云山上，16岁这年代替妹妹千云裳嫁入夜王府，传说夜幽冥性情古怪，冷酷残暴，千云兮将会经历怎样的遭遇呢。。。。。。◎恋爱 ◎爆笑 ◎唯美 ◎
# 妖怪名单◎ 210.7亿◎ http://ac.qq.com/Comic/comicInfo/id/521825 ◎魅惑众生的九尾狐狸？吸人精气的合欢树妖？道家妹子求双修，仙家女神若即离。游走在这些危险分子中间可不是容易的事情。但为了世界和平，少年封夕豁出去啦！每周尽力周二周六更新！实在画不完随时盯着更新吧~作品群：595275406，595274283，342499102。目前官方群仅此三个，欢迎进群讨论~◎玄幻 ◎后宫 ◎恋爱 ◎
# 尸兄（我叫白小◎ 175.3亿◎ http://ac.qq.com/Comic/comicInfo/id/17114 ◎即将毁灭的世界......每周更新...◎恐怖 ◎爆笑 ◎冒险 ◎
# 王牌御史◎ 162.7亿◎ http://ac.qq.com/Comic/comicInfo/id/519855 ◎昼夜颠倒的新时代，勤劳的御史大人们降妖除魔打怪兽的欢乐故事~~在一个蛇精病一样爱好行为艺术的男主和一个穿着古装脾气暴躁上来就"跳楼"倒霉透顶的黑长直妹子中展开，漫画每周一周五更新。◎玄幻 ◎爆笑 ◎都市 ◎
# 猫妖的诱惑◎ 161.2亿◎ http://ac.qq.com/Comic/comicInfo/id/552724 ◎【周三周六更新】精分猫妖带着前世记忆重生，扬言要找前世恋人复仇，但是看到他就好想亲亲扑倒怎么办？！看史上最没节操的女主在高冷禁欲男神和邪魅冷艳妖王之间，如何抉择！◎恋爱 ◎玄幻 ◎唯美 ◎
# 火影忍者◎ 153.1亿◎ http://ac.qq.com/Comic/comicInfo/id/505432 ◎list index out of range ◎热血 ◎动作 ◎冒险 ◎
# 中国惊奇先生◎ 150.2亿◎ http://ac.qq.com/Comic/comicInfo/id/511915 ◎身怀神鬼七杀令的屌丝青年王小二，初涉职场的美女警花李雪，心地善良的痴情小狐狸……漫画每周一三五更新（手机客户端提前1天更新），动画每周二更新，感谢大家一如既往的支持，中国惊奇先生粉丝娱乐群（群号码：93277487）已满，欢迎加入中国惊奇先生粉丝娱乐二群，群号码：273942387◎恐怖 ◎惊险 ◎爆笑 ◎
# 航海王◎ 145.9亿◎ http://ac.qq.com/Comic/comicInfo/id/505430 ◎list index out of range ◎热血 ◎冒险 ◎爆笑 ◎
# 一人之下◎ 142.9亿◎ http://ac.qq.com/Comic/comicInfo/id/531490 ◎大学生张楚岚清明回乡，遭遇神秘少女冯宝宝。素未谋面的冯宝宝却对张楚岚异常熟悉，并将其带去自己打工的快递公司。为了帮冯宝宝寻找她的身世，也为了查清自己与爷爷身上的秘密，张楚岚的生活被彻底颠覆，与冯宝宝一同踏上"异人"之旅。◎玄幻 ◎格斗 ◎爆笑 ◎
# 银之守墓人◎ 134.1亿◎ http://ac.qq.com/Comic/comicInfo/id/525550 ◎穷苦高中生陆水银是个游戏达人，突然他意外获得5亿遗产却不料全是游戏币，接着心仪的女生被绑架，一连窜神秘事件更是接踵而至，他也被迫穿越到“盗墓者游戏”的世界里。带着5亿陵币和“最后的守墓人”的身份，加入到这场盗墓者与守墓人的神秘游戏中。公众号：yzsmr210；请大伙呼唤朋友来收藏大大方方投月票◎玄幻 ◎冒险 ◎竞技 ◎
# 狐妖小红娘◎ 123亿◎ http://ac.qq.com/Comic/comicInfo/id/518333 ◎迷糊萝莉小狐妖，正太道士没节操。自古人妖生死恋，千载孽缘一线牵！（注：现在起狐妖每周三、六更新。）◎玄幻 ◎恋爱 ◎爆笑 ◎
# 斗破苍穹◎ 122亿◎ http://ac.qq.com/Comic/comicInfo/id/531040 ◎正所谓三十年河东三十年河西，天才少年因忽然失去了天生的灵力，被所有人嘲笑排挤，为了一雪前耻他亲手毁掉婚约，一心进修、打怪、升级！重登人生巅峰的他让人们知道莫欺少年穷真的很重要！【授权】◎热血 ◎魔幻 ◎动作 ◎

# %%
import re

# %%
import os
import sys
import json
import re
import requests
import html
import time
import urllib.request
import pandas as pd
from bs4 import BeautifulSoup

# %%
data = {"name": col1, "people": col2, "book_url": col3,"body": col4}
df = pd.DataFrame(data)
df = df[["name", "people", "book_url", "body"]]

# %%
result_list = []
#for i in range(len(df)):
#    result_list.append(df)
result_list.append(df)
df1 = pd.concat(result_list)
df1.to_csv("qq.csv")

# %%
import csv
writer = csv.writer(open('qq3.csv', 'rt', encoding='utf-8', errors='ignore'), delimiter = ',')
for row in zip(col1, col2, col3, col4):
    print(row)
    writer.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-840440f4c0a2> in <module>()
#       1 import csv
# ----> 2 writer = csv.writer(open('qq3.csv', 'rt', encoding='utf-8', errors='ignore'), delimiter = ',')
#       3 for row in zip(col1, col2, col3, col4):
#       4     print(row)
#       5     writer.writerow(row)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'qq3.csv'
